# %% [markdown]
# <h1 align="center">Speech Enhancement</h1>

# %% [markdown]
# Data Scientist.: Dr.Eddy Giusepe Chirinos Isidro

# %% [markdown]
# O objetivo do aprimoramento da fala é `remover o ruído` que afeta uma gravação. A `speechbrain` possui vários sistemas para aprimoramento de fala. A seguir, você encontra um exemplo processado pelo `SepFormer` (a versão treinada para realizar o aprimoramento).

# %%
import torchaudio
import speechbrain as sb
from speechbrain.dataio.dataio import read_audio
from IPython.display import Audio
from speechbrain.pretrained import SepformerSeparation as separator

# %%
model = separator.from_hparams(source="speechbrain/sepformer-whamr-enhancement", savedir='pretrained_models/sepformer-whamr-enhancement')
# Out:
# Downloading: 100%|██████████| 5.24k/5.24k [00:00<00:00, 978kB/s]
# Downloading: 100%|██████████| 17.3k/17.3k [00:00<00:00, 844kB/s]
# Downloading: 100%|██████████| 113M/113M [01:13<00:00, 1.54MB/s]
# Downloading: 100%|██████████| 17.3k/17.3k [00:00<00:00, 598kB/s]

# %%
enhanced_speech = model.separate_file(path='speechbrain/sepformer-whamr-enhancement/example_whamr.wav')
# Out:
# Downloading: 100%|██████████| 164k/164k [00:00<00:00, 271kB/s]

# %%
signal = read_audio("example_whamr.wav").squeeze()
Audio(signal, rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(enhanced_speech[:, :].detach().cpu().squeeze(), rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Abaixo apresentamos mais um exemplo com um áudio da Vale

# %% [markdown]
# ## exemplo 1:

# %%
# Outro exemplo:
enhanced_speech = model.separate_file(path='/home/eddygiusepe/Imagens/Eddy_codigos/speech_processing/studying_speechbrain_1/fabio_teste.WAV')

# %%
signal = read_audio("./fabio_teste.WAV").squeeze()
Audio(signal, rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(enhanced_speech[:, :].detach().cpu().squeeze(), rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Exemplo 2:

# %%
signal = read_audio("./teste_vale.WAV").squeeze()
Audio(signal, rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Outro exemplo:
enhanced_speech = model.separate_file(path='./teste_vale.WAV')

# %%
Audio(enhanced_speech[:, :].detach().cpu().squeeze(), rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
